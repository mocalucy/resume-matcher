# %%
# !pip install PyPDF2
import PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
def read_pdf(file_path):
    output = None
    try:
        pdf_obj = open(file_path, 'rb')
        pdf_reader = PyPDF2.PdfReader(pdf_obj)
        page_obj = pdf_reader.pages[0]
        output = page_obj.extract_text()
        pdf_obj.close()
    except Exception as e:
        print(f"Error reading file '{file_path}': {str(e)}")
    return output

# %%
from google.colab import drive
drive.mount('/content/drive')
test = read_pdf('/content/drive/MyDrive/resume-match/data/resume/Mani_Kanta_Gogula_Resume.pdf')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### PREPARE TRAINING DATASET
# resume1 = read_pdf('data/Mani_Kanta_Gogula_Resume.pdf')
# #resume1
# with open('resume1.txt', 'w') as f:
#     f.write(resume1)

# %% [markdown]
# ### text cleaning

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
def clean_text(s):
  tokens = word_tokenize(s.lower())
  tokens = [WordNetLemmatizer().lemmatize(t) for t in tokens if t not in set(stopwords.words('english') + list(string.punctuation))]
  return ' '.join(tokens)

# %%
clean_test = clean_text(test)

# %%
clean_test
# Out:
# 'mani kanta gogula ph:413 -315-1056 |mgogula46 gmail.com linkedin education m.s data business analytics| university massachusetts amherst |gpa 3.85/4 jan 22 – dec 23 course data science fundamental business intelligence analytics machine learning quantitative analysis data mining b.tech electronics communication engineering| jawaharlal nehru technological university aug 15 june19 relevant coursework mathematical method probability statistic managerial economics financial analysis professional experience business analyst intern product ops analytics experian may 2023 aug 2023 • developed executed sql query aggregate analyze interpret business data enabling comprehensive quantitative qualitative analysis insight support decision -making contributed success experian consumer service ec product service • partnered closely product technology customer care bizops external partner track address resolve customer escalation resulting 25 decrease customer support ticket 10 increase first -call resolution rate • analyzed 50+ customer escalated ticket monthly identify top 3 product improvement opportunity presented finding senior leadership • instrumental facilitating ad-hoc business analysis delivering invaluable insight strategic recommendation drive optimization strategy collaborated seamlessly stakeholder pinpoint avenue refining product streamlining operational workflow enhancing overall business process • created comprehensive analysis playbook encompassing diverse service level playbook entail workflow handling escalation provides corresponding sql python script effectively address escalated issue • identified escalated multiple miscategorized tradelines impacted 3000 customer credit score positively boost product • contributed customer feedback analysis project skillfully utilizing excel tableau python generate impactful visualization revealing significant trend across 12 -month dataset • collaborated team create python automation script investigating marketplace issue achieving runtime 2 minute transaction risk payment risk ops amazon sep 2019 dec 2021 • collaborated analyst subject matter expert decision -makers develop data -driven policy model enhancing process performance meeting service level agreement slas • conducted data extraction integrity check metric generation ad hoc analysis ensure data accuracy facilitate investigative effort • identified documented fraud trend pattern complex datasets across diverse marketplace resulting development standard operating procedure sop fraud prevention • mentored team 10 individual development fraud detection protocol leading 30 increase team production quality metric • acted point contact risk investigation team product development team improving internal tool simplifying understanding customer behavioral pattern • successfully identified prevented fraudulent attack 1000+ customer account detecting different account take ato fraud technique ongoing sale • initiated executed internal project collaboration cross -functional team identify repeat customer contact large volume datasets resulting 40 reduction repeat contact • developed comprehensive dashboard reporting model provide accurate insight key stakeholder leadership aiding decision -making process policy • analyzed unstructured behavioral data detect address fraud scheme across multiple marketplace resulting creation effective standard operating procedure sop fraud mitigation • worked closely business analytics data science team monitor credit fraud strategy kpis marketplace performance skill • programming scripting language python r sql • tool tableau m excel m office sharepoint git xlminer jupyter qualtrics jira confluence salesforce • packages/libraries panda numpy matplotlib ggplot2 tidyverse dplyr sentimentr textmining quanteda rtweet • business project management negotiation customer relationship management problem solving cross -functional collaboration stakeholder relationship user accep tance testing on-call support kanb ...

# %% [markdown]
# ### EXTRACTING DATA

# %%
import re
import spacy
import spacy_transformers
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# !pip install spacy-transformers
# Out:
# Collecting spacy-transformers
#   Downloading spacy_transformers-1.3.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.9/197.9 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<4.0.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers) (3.7.4)
# Collecting transformers<4.37.0,>=3.4.0 (from spacy-transformers)
#   Downloading transformers-4.36.2-py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 56.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers) (2.2.1+cu121)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers) (2.4.8)
# Collecting spacy-alignments<1.0.0,>=0.7.2 (from spacy-transformers)
#   Downloading spacy_alignments-0.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.0/314.0 kB 36.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy-transformers) (1.25.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (1.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (2.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->spacy-transformers) (3.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers) (3.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->spacy-transformers)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->spacy-transformers)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->spacy-transformers)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8.0->spacy-transformers)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->spacy-transformers)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->spacy-transformers)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->spacy-transformers)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->spacy-transformers)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->spacy-transformers)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.8.0->spacy-transformers)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->spacy-transformers)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->spacy-transformers) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->spacy-transformers)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (0.20.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<4.37.0,>=3.4.0->spacy-transformers) (0.4.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.5.0->spacy-transformers) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.5.0->spacy-transformers) (2.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.5.0->spacy-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.5.0->spacy-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.5.0->spacy-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.5.0->spacy-transformers) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.5.0->spacy-transformers) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.5.0->spacy-transformers) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<4.0.0,>=3.5.0->spacy-transformers) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<4.0.0,>=3.5.0->spacy-transformers) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<4.0.0,>=3.5.0->spacy-transformers) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->spacy-transformers) (1.3.0)
# Installing collected packages: spacy-alignments, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, transformers, spacy-transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 spacy-alignments-0.9.1 spacy-transformers-1.3.4 transformers-4.36.2

# %%
nlp_trained = spacy.load('/content/drive/MyDrive/resume-match/output/model-best')

# %%
test_doc = nlp(clean_test)
test_doc_trained = nlp_trained(test)

# %%
def extract_names(nlp_text):  #need some filter
    return [e.text for e in nlp_text.ents if e.label_ == 'PERSON'][0]

# %%
extract_names(test_doc)
# Out:
# 'mani kanta gogula'

# %%
def extract_education(nlp_text):
  return [e.text for e in nlp_text.ents if e.label_ == 'DEGREE']

# %%
extract_education(test_doc_trained)
# Out:
# ['M.S.  Data  & Business  Analytics|',
#  'B.Tech.  Electronics  and Communication  Engineering|  Jawaharlal Nehru  Technological  University']

# %%
def extract_emails(text):
    email_pattern = r'\w+@\S+\.\S+'
    return re.findall(email_pattern, text)

# %%
extract_emails(test)
# Out:
# ['mgogula46@gmail.com']

# %%
def extract_phones(text):
    phone_pattern = r'[+]?[0-9]{0,3}\s?[(]?[1-9][0-9]{2}[)\-\s]*[0-9]{3}[\-\s]?[0-9]{4}'
    phones = re.findall(phone_pattern, text)
    phone = []
    for p in phones:
      phone.append("".join([i for i in p if i.isnumeric()]))
    return phone

# %%
extract_phones(test)
# Out:
# ['4133151056']

# %%
def extract_links(text):
    link_pattern = r'(?:https?://|www\.)\S+'
    return re.findall(link_pattern, text)

# %%
extract_links(test)
# Out:
# []

# %%
def extract_entities(nlp_text): #education/previous company
    entity_labels = ['GPE', 'ORG']
    entities = [e.text for e in nlp_text.ents if e.label_ in entity_labels]
    return entities

# %%
extract_entities(test_doc)
# Out:
# ['m.s data business', '|gpa', 'ec', 'kanban']

# %%
RESUME_SECTIONS = [
    'Contact Information',
    'Objective',
    'Summary',
    'Education',
    'Experience',
    'Skills',
    'Projects',
    'Certifications',
    'Licenses',
    'Awards',
    'Honors',
    'Publications',
    'References',
    'Technical Skills',
    'Computer Skills',
    'Programming Languages',
    'Software Skills',
    'Soft Skills',
    'Language Skills',
    'Professional Skills',
    'Transferable Skills',
    'Work Experience',
    'Professional Experience',
    'Employment History',
    'Internship Experience',
    'Volunteer Experience',
    'Leadership Experience',
    'Research Experience',
    'Teaching Experience'
]
EXPERIENCE_SECTIONS = [
    'Experience',
    'Work Experience',
    'Professional Experience',
    'Employment History',
    'Internship Experience',
    'Volunteer Experience',
    'Leadership Experience',
    'Research Experience',
    'Teaching Experience'
]
EXPERIENCE_SECTIONS = [i.lower() for i in EXPERIENCE_SECTIONS]

# %%
def extract_experience(nlp_text):
    experience_section = []
    in_experience_section = False

    for token in nlp_text:
        if token.text == 'experience':
            in_experience_section = True
            #print(token.text)
        if in_experience_section:
            #print(token.text)
            experience_section.append(token.text)
    return " ".join(experience_section)

# %%
extract_experience(test_doc)
# Out:
# 'experience business analyst intern product ops analytics experian may 2023 aug 2023 • developed executed sql query aggregate analyze interpret business data enabling comprehensive quantitative qualitative analysis insight support decision -making contributed success experian consumer service ec product service • partnered closely product technology customer care bizops external partner track address resolve customer escalation resulting 25 decrease customer support ticket 10 increase first -call resolution rate • analyzed 50 + customer escalated ticket monthly identify top 3 product improvement opportunity presented finding senior leadership • instrumental facilitating ad - hoc business analysis delivering invaluable insight strategic recommendation drive optimization strategy collaborated seamlessly stakeholder pinpoint avenue refining product streamlining operational workflow enhancing overall business process • created comprehensive analysis playbook encompassing diverse service level playbook entail workflow handling escalation provides corresponding sql python script effectively address escalated issue • identified escalated multiple miscategorized tradelines impacted 3000 customer credit score positively boost product • contributed customer feedback analysis project skillfully utilizing excel tableau python generate impactful visualization revealing significant trend across 12 -month dataset • collaborated team create python automation script investigating marketplace issue achieving runtime 2 minute transaction risk payment risk ops amazon sep 2019 dec 2021 • collaborated analyst subject matter expert decision -makers develop data -driven policy model enhancing process performance meeting service level agreement slas • conducted data extraction integrity check metric generation ad hoc analysis ensure data accuracy facilitate investigative effort • identified documented fraud trend pattern complex datasets across diverse marketplace resulting development standard operating procedure sop fraud prevention • mentored team 10 individual development fraud detection protocol leading 30 increase team production quality metric • acted point contact risk investigation team product development team improving internal tool simplifying understanding customer behavioral pattern • successfully identified prevented fraudulent attack 1000 + customer account detecting different account take ato fraud technique ongoing sale • initiated executed internal project collaboration cross -functional team identify repeat customer contact large volume datasets resulting 40 reduction repeat contact • developed comprehensive dashboard reporting model provide accurate insight key stakeholder leadership aiding decision -making process policy • analyzed unstructured behavioral data detect address fraud scheme across multiple marketplace resulting creation effective standard operating procedure sop fraud mitigation • worked closely business analytics data science team monitor credit fraud strategy kpis marketplace performance skill • programming scripting language python r sql • tool tableau m excel m office sharepoint git xlminer jupyter qualtrics jira confluence salesforce • packages / libraries panda numpy matplotlib ggplot2 tidyverse dplyr sentimentr textmining quanteda rtweet • business project management negotiation customer relationship management problem solving cross -functional collaboration stakeholder relationship user accep tance testing on - call support kanban bord management business process improvement • statistic regre ssion hypothesis testing machine learning technique data anal ysis statistical modeling probability sampling technique award • winner quality acer star performance 2019 mitigating identity fraud amazon • 3x best employee month year 2020 amazon project comparative analysis machine learning technique fraud detection |data science python heart disease prediction logistic regression data science r programming sentiment anal ...

# %%
def extract_position_year(text):
  position_year_search_pattern = r"(\b\w+\b\s+\b\w+\b),\s+(\d{4})\s*-\s*(\d{4}|\bpresent\b)"
  position_year = re.findall(position_year_search_pattern, text)
  return position_year

# %%
extract_position_year(test)
# Out:
# []

# %%
def extract_keywords(nlp_text):
  return [t.text for t in nlp_text if t.pos_ in ['NOUN', 'PROPN']]

# %%
extract_keywords(test_doc)
# Out:
# ['mani',
#  'gogula',
#  'ph:413',
#  '-315',
#  '|mgogula46',
#  'gmail.com',
#  'linkedin',
#  'education',
#  'm.s',
#  'data',
#  'business',
#  'university',
#  'massachusetts',
#  '|gpa',
#  'jan',
#  'dec',
#  'course',
#  'data',
#  'science',
#  'business',
#  'intelligence',
#  'analytics',
#  'machine',
#  'analysis',
#  'data',
#  'mining',
#  'electronics',
#  'communication',
#  'engineering|',
#  'jawaharlal',
#  'nehru',
#  'university',
#  'aug',
#  'june19',
#  'coursework',
#  'method',
#  'probability',
#  'economics',
#  'analysis',
#  'experience',
#  'business',
#  'analyst',
#  'intern',
#  'product',
#  'ops',
#  'analytics',
#  'aug',
#  'query',
#  'aggregate',
#  'analyze',
#  'business',
#  'data',
#  'analysis',
#  'insight',
#  'support',
#  'decision',
#  '-making',
#  'success',
#  'consumer',
#  'service',
#  'ec',
#  'product',
#  'service',
#  'product',
#  'technology',
#  'customer',
#  'care',
#  'partner',
#  'track',
#  'address',
#  'customer',
#  'escalation',
#  'decrease',
#  'customer',
#  'support',
#  'ticket',
#  'increase',
#  '-call',
#  'resolution',
#  'rate',
#  'customer',
#  'ticket',
#  'product',
#  'improvement',
#  'opportunity',
#  'leadership',
#  'ad',
#  'business',
#  'analysis',
#  'insight',
#  'recommendation',
#  'drive',
#  'optimization',
#  'strategy',
#  'stakeholder',
#  'avenue',
#  'refining',
#  'product',
#  'workflow',
#  'business',
#  'process',
#  'analysis',
#  'playbook',
#  'service',
#  'level',
#  'playbook',
#  'entail',
#  'workflow',
#  'handling',
#  'escalation',
#  'sql',
#  'python',
#  'script',
#  'address',
#  'issue',
#  'tradelines',
#  'customer',
#  'credit',
#  'score',
#  'product',
#  'customer',
#  'feedback',
#  'analysis',
#  'project',
#  'excel',
#  'tableau',
#  'python',
#  'visualization',
#  'trend',
#  '-month',
#  'team',
#  'python',
#  'automation',
#  'script',
#  'marketplace',
#  'issue',
#  'runtime',
#  'minute',
#  'transaction',
#  'risk',
#  'payment',
#  'risk',
#  'ops',
#  'amazon',
#  'sep',
#  'dec',
#  'analyst',
#  'subject',
#  'matter',
#  'expert',
#  'decision',
#  '-makers',
#  'data',
#  'policy',
#  'model',
#  'process',
#  'performance',
#  'meeting',
#  'service',
#  'level',
#  'agreement',
#  'data',
#  'extraction',
#  'integrity',
#  'generation',
#  'analysis',
#  'data',
#  'accuracy',
#  'facilitate',
#  'effort',
#  'fraud',
#  'trend',
#  'pattern',
#  'datasets',
#  'marketplace',
#  'development',
#  'operating',
#  'procedure',
#  'sop',
#  'fraud',
#  'prevention',
#  'team',
#  'development',
#  'fraud',
#  'detection',
#  'protocol',
#  'increase',
#  'team',
#  'production',
#  'quality',
#  'point',
#  'contact',
#  'risk',
#  'investigation',
#  'team',
#  'product',
#  'development',
#  'team',
#  'tool',
#  'customer',
#  'pattern',
#  'attack',
#  'customer',
#  'account',
#  'account',
#  'fraud',
#  'technique',
#  'sale',
#  'project',
#  'collaboration',
#  'cross',
#  'team',
#  'repeat',
#  'customer',
#  'contact',
#  'volume',
#  'datasets',
#  'reduction',
#  'repeat',
#  'contact',
#  'dashboard',
#  'reporting',
#  'model',
#  'insight',
#  'stakeholder',
#  'leadership',
#  'decision',
#  'process',
#  'policy',
#  'data',
#  'address',
#  'fraud',
#  'scheme',
#  'marketplace',
#  'creation',
#  'operating',
#  'procedure',
#  'sop',
#  'fraud',
#  'mitigation',
#  'business',
#  'analytics',
#  'data',
#  'science',
#  'team',
#  'credit',
#  'fraud',
#  'strategy',
#  'marketplace',
#  'performance',
#  'skill',
#  'programming',
#  'scripting',
#  'language',
#  'python',
#  'r',
#  'tool',
#  'tableau',
#  'm',
#  'excel',
#  'm',
#  'office',
#  'sharepoint',
#  'git',
#  'xlminer',
#  'jupyter',
#  'qualtrics',
#  'jira',
#  'confluence',
#  'packages',
#  'panda',
#  'numpy',
#  'matplotlib',
#  'ggplot2',
#  'tidyverse',
#  'dplyr',
#  'sentimentr',
#  'business',
#  'project',
#  'management',
#  'negotiation',
#  'customer',
#  'relationship',
#  'management',
#  'problem',
#  'cross',
#  'collaboration',
#  'stakeholder',
#  'relationship',
#  'user',
#  'tance',
#  'testing',
#  'call',
#  'support',
#  'kanban',
#  'bord',
#  'management',
#  'business',
#  'process',
#  'improvement',
#  'regre',
#  'ssion',
#  'hypothesis',
#  'testing',
#  'machine',
#  'technique',
#  'data',
#  'ysis',
#  'modeling',
#  'probability',
#  'technique',
#  'award',
#  'winner',
#  'quality',
#  'acer',
#  'star',
#  'performance',
#  'identity',
#  'fraud',
#  'amazon',
#  'employee',
#  'month',
#  'year',
#  'amazon',
#  'project',
#  'analysis',
#  'machine',
#  'technique',
#  'fraud',
#  'detection',
#  '|data',
#  'science',
#  'python',
#  'heart',
#  'disease',
#  'prediction',
#  'regression',
#  'data',
#  'science',
#  'r',
#  'programming',
#  'sentiment',
#  'analysis',
#  'text',
#  'analysis',
#  'data',
#  'science',
#  'r',
#  'programming',
#  'usage',
#  'data',
#  'analysis',
#  'visualization',
#  'sql',
#  'tableau']

# %%
def to_JSON(text):
  clean_data = clean_text(text)
  nlp_doc = nlp(clean_data)
  resume_dict = {
      'resume': text,
      'clean_text': clean_data,
      'name': extract_names(nlp_doc),
      'email': extract_emails(text),
      'phone': extract_phones(text),
      'link': extract_links(text),
      'keywords': extract_keywords(nlp_doc),
      'education': extract_education(nlp_trained(text)),
      'experience': extract_experience(nlp_doc)
  }
  return resume_dict

# %%
import json
json_object = json.dumps(to_JSON(test), sort_keys=True)
with open("/content/drive/MyDrive/resume-match/data/extracted_resume.json", "w+") as outfile:
  outfile.write(json_object)
